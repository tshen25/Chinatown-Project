# %%
# import libraries
from census import Census
import requests
import pandas as pd
import time

# --- USER CONFIG ---
CENSUS_API_KEY = "827d2bde6c4a712da4432fb6f1e392a040ee9c6b"   
c = Census(CENSUS_API_KEY)

# %%
# setup
# Representative Chinatown addresses - core locations for better geocoding
chinatowns = {
    "Boston": "88 Beach Street, Boston, MA 02111",
    "New York": "70 Bayard Street, New York, NY 10013",
    "Philadelphia": "1001 Race St, Philadelphia, PA 19107",
    "Washington DC": "701 H Street NW, Washington, DC 20001",
    "Cleveland": "2136 Rockwell Ave, Cleveland, OH 44114",
    "Chicago": "2206 S Wentworth Ave, Chicago, IL 60616",
    "Seattle": "668 S King St, Seattle, WA 98104",
    "Portland": "133 NW 4th Avenue, Portland, OR 97209",
    "Oakland": "388 9th St, Oakland, CA 94607",
    "San Francisco": "839 Stockton Street, San Francisco, CA 94108",
    "Fresno": "1001 F St, Fresno, CA 93706",
    "Los Angeles": "727 N Broadway, Los Angeles, CA 90012",
}

# Cities that need 2010 tract substitution (tract boundaries changed)
CROSSWALK_CITIES = ["Boston", "New York", "Washington DC", "Portland"]

# --- LOAD CROSSWALK FILE ---
# Assumes pipe-delimited file
crosswalk = pd.read_csv("crosswalk.txt", sep="|", dtype=str)
crosswalk = crosswalk[["GEOID_TRACT_20", "GEOID_TRACT_10"]].drop_duplicates()

# %%
# def functions
def get_2010_geoid_from_2020(geoid_20):
    """Return the 2010 GEOID that corresponds to the given 2020 GEOID."""
    match = crosswalk.loc[crosswalk["GEOID_TRACT_20"] == geoid_20, "GEOID_TRACT_10"]
    return match.iloc[0] if not match.empty else None

# --- FUNCTIONS ---
def geocode_to_tract(address, max_retries=3):
    """Use Census Geocoder to get tract GEOID for an address (2020 boundaries)."""
    url = "https://geocoding.geo.census.gov/geocoder/geographies/onelineaddress"
    
    for attempt in range(max_retries):
        try:
            params = {
                "address": address,
                "benchmark": "Public_AR_Current",
                "vintage": "Current_Current",
                "format": "json"
            }
            r = requests.get(url, params=params, timeout=15)
            r.raise_for_status()
            data = r.json()
            
            matches = data.get("result", {}).get("addressMatches", [])
            if not matches:
                print(f"    No matches found for: {address}")
                return None, None, None
                
            tract = matches[0]["geographies"]["Census Tracts"][0]
            geoid = tract["GEOID"]
            state = tract["STATE"]
            county = tract["COUNTY"]
            
            return geoid, state, county
            
        except (IndexError, KeyError) as e:
            print(f"    Parse error (attempt {attempt+1}/{max_retries}): {e}")
        except requests.exceptions.RequestException as e:
            print(f"    Request error (attempt {attempt+1}/{max_retries}): {e}")
        
        if attempt < max_retries - 1:
            time.sleep(2)
    
    return None, None, None


def fetch_acs5_population(year, state_fips, county_fips, tract):
    """Fetch total and Asian population from ACS5 for a single tract/year."""
    try:
        # Only need total population and Asian alone
        variables = ("B01003_001E", "B02001_005E")
        
        data = c.acs5.state_county_tract(
            variables, state_fips, county_fips, tract, year=year
        )
        
        if data and len(data) > 0:
            total_pop = int(data[0].get("B01003_001E", 0))
            asian_pop = int(data[0].get("B02001_005E", 0))
            
            return {
                "year": year,
                "source": "acs5",
                "total_pop": total_pop,
                "asian_pop": asian_pop,
            }
        else:
            print(f"    No ACS5 data returned for {year}")
            return None
            
    except Exception as e:
        print(f"    Error fetching {year}: {e}")
        return None

# %%
# --- MAIN EXECUTION ---
results = []

# Full year range from 2010 to 2023
years = list(range(2010, 2025))  # 2010-2023

print("="*60)
print("CHINATOWN DEMOGRAPHICS - ACS5 DATA COLLECTION (2010-2023)")
print("="*60)

for city, addr in chinatowns.items():
    print(f"\n📍 Processing {city}...")
    
    # Get 2020 tract boundaries
    geoid_2020, state_fips, county_fips = geocode_to_tract(addr)
    
    if not geoid_2020:
        print(f"  ❌ Could not find tract for {city}")
        continue

    tract_2020 = geoid_2020[-6:]
    print(f"  ✓ 2020 GEOID: {geoid_2020}")
    print(f"    State: {state_fips}, County: {county_fips}, Tract: {tract_2020}")
    
    # If city needs crosswalk, get 2010 tract
    geoid_2010 = None
    tract_2010 = None
    if city in CROSSWALK_CITIES:
        geoid_2010 = get_2010_geoid_from_2020(geoid_2020)
        if geoid_2010:
            tract_2010 = geoid_2010[-6:]
            print(f"  ✓ 2010 GEOID: {geoid_2010} (via crosswalk)")
        else:
            print(f"  ⚠ Warning: No 2010 tract found in crosswalk for {geoid_2020}")
            print(f"    Will attempt to use 2020 tract for all years")

    # Process each year
    for y in years:
        # Determine which tract to use based on year and city
        if city in CROSSWALK_CITIES and y <= 2019 and geoid_2010:
            # Use 2010 tract boundaries for 2010-2019
            tract_for_year = tract_2010
            geoid_for_year = geoid_2010
            period_label = "2010-2019"
        else:
            # Use 2020 tract boundaries for 2020-2023 (or all years for non-crosswalk cities)
            tract_for_year = tract_2020
            geoid_for_year = geoid_2020
            period_label = "2020-2023" if y >= 2020 else "default"
        
        # Only print tract info on first use or when switching periods
        if y == 2010 or (city in CROSSWALK_CITIES and y == 2020):
            print(f"    → Using tract {tract_for_year} for {period_label}")
        
        pop = fetch_acs5_population(y, state_fips, county_fips, tract_for_year)
        if pop:
            pop["city"] = city
            pop["tract_geoid"] = geoid_for_year
            results.append(pop)
            print(f"    ✓ {y}: Total Pop={pop['total_pop']:,}, Asian Pop={pop['asian_pop']:,}")
        
        time.sleep(0.3)  # Rate limiting

print("\n" + "="*60)
print("COLLECTED DATA")
print("="*60)

df = pd.DataFrame(results)
if not df.empty:
    # Display full results
    print(df[['city', 'year', 'total_pop', 'asian_pop', 'tract_geoid']].to_string(index=False))
    
    print("\n" + "="*60)
    print("DATA SUMMARY")
    print("="*60)
    print(f"Total records collected: {len(df)}")
    print(f"Cities with data: {df['city'].nunique()}")
    print(f"Year range: {df['year'].min()} - {df['year'].max()}")
    
    # Records per city
    print("\nRecords per city:")
    print(df.groupby('city').size().sort_values(ascending=False))
    
    # Save to CSV
    df.to_csv('chinatown_demographics.csv', index=False)
    print("\n✅ Data saved to chinatown_demographics.csv")
else:
    print("❌ No data collected.")
# Out:
# ============================================================
# CHINATOWN DEMOGRAPHICS - ACS5 DATA COLLECTION (2010-2023)
# ============================================================
#
# 📍 Processing Boston...
#   ✓ 2020 GEOID: 25025070202
#     State: 25, County: 025, Tract: 070202
#   ✓ 2010 GEOID: 25025070101 (via crosswalk)
#     → Using tract 070101 for 2010-2019
#     ✓ 2010: Total Pop=4,694, Asian Pop=1,516
#     ✓ 2011: Total Pop=5,174, Asian Pop=1,593
#     ✓ 2012: Total Pop=5,494, Asian Pop=1,182
#     ✓ 2013: Total Pop=5,597, Asian Pop=1,510
#     ✓ 2014: Total Pop=5,499, Asian Pop=1,210
#     ✓ 2015: Total Pop=5,668, Asian Pop=1,301
#     ✓ 2016: Total Pop=6,212, Asian Pop=1,901
#     ✓ 2017: Total Pop=6,496, Asian Pop=1,842
#     ✓ 2018: Total Pop=7,075, Asian Pop=2,447
#     ✓ 2019: Total Pop=7,409, Asian Pop=2,364
#     → Using tract 070202 for 2020-2023
#     ✓ 2020: Total Pop=3,727, Asian Pop=2,638
#     ✓ 2021: Total Pop=3,626, Asian Pop=2,531
#     ✓ 2022: Total Pop=4,233, Asian Pop=2,413
#     ✓ 2023: Total Pop=4,136, Asian Pop=2,419
#     Error fetching 2024: Geography is not available in 2024. Available years include (2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009)
#
# 📍 Processing New York...
#   ✓ 2020 GEOID: 36061002902
#     State: 36, County: 061, Tract: 002902
#   ✓ 2010 GEOID: 36061002900 (via crosswalk)
#     → Using tract 002900 for 2010-2019
#     ✓ 2010: Total Pop=6,939, Asian Pop=5,192
#     ✓ 2011: Total Pop=6,839, Asian Pop=5,051
#     ✓ 2012: Total Pop=6,385, Asian Pop=4,649
#     ✓ 2013: Total Pop=5,855, Asian Pop=4,127
#     ✓ 2014: Total Pop=5,841, Asian Pop=4,118
#     ✓ 2015: Total Pop=6,050, Asian Pop=4,014
#     ✓ 2016: Total Pop=6,110, Asian Pop=3,799
#     ✓ 2017: Total Pop=6,869, Asian Pop=4,793
#     ✓ 2018: Total Pop=6,365, Asian Pop=4,147
#     ✓ 2019: Total Pop=5,924, Asian Pop=3,489
#     → Using tract 002902 for 2020-2023
#     ✓ 2020: Total Pop=4,151, Asian Pop=3,451
#     ✓ 2021: Total Pop=4,197, Asian Pop=3,472
#     ✓ 2022: Total Pop=3,885, Asian Pop=3,160
#     ✓ 2023: Total Pop=3,832, Asian Pop=3,204
#     Error fetching 2024: Geography is not available in 2024. Available years include (2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009)
#
# 📍 Processing Philadelphia...
#   ✓ 2020 GEOID: 42101000200
#     State: 42, County: 101, Tract: 000200
#     → Using tract 000200 for default
#     ✓ 2010: Total Pop=1,919, Asian Pop=1,519
#     ✓ 2011: Total Pop=1,897, Asian Pop=1,443
#     ✓ 2012: Total Pop=2,009, Asian Pop=1,231
#     ✓ 2013: Total Pop=2,215, Asian Pop=1,420
#     ✓ 2014: Total Pop=2,285, Asian Pop=1,277
#     ✓ 2015: Total Pop=2,331, Asian Pop=1,183
#     ✓ 2016: Total Pop=2,563, Asian Pop=1,389
#     ✓ 2017: Total Pop=2,683, Asian Pop=1,626
#     ✓ 2018: Total Pop=2,576, Asian Pop=1,546
#     ✓ 2019: Total Pop=2,860, Asian Pop=1,865
#     ✓ 2020: Total Pop=3,175, Asian Pop=1,898
#     ✓ 2021: Total Pop=3,414, Asian Pop=1,888
#     ✓ 2022: Total Pop=3,486, Asian Pop=1,724
#     ✓ 2023: Total Pop=3,259, Asian Pop=1,392
#     Error fetching 2024: Geography is not available in 2024. Available years include (2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009)
#
# 📍 Processing Washington DC...
#   ✓ 2020 GEOID: 11001005802
#     State: 11, County: 001, Tract: 005802
#   ✓ 2010 GEOID: 11001005800 (via crosswalk)
#     → Using tract 005800 for 2010-2019
#     ✓ 2010: Total Pop=2,675, Asian Pop=582
#     ✓ 2011: Total Pop=2,784, Asian Pop=571
#     ✓ 2012: Total Pop=2,678, Asian Pop=562
#     ✓ 2013: Total Pop=2,664, Asian Pop=530
#     ✓ 2014: Total Pop=2,697, Asian Pop=594
#     ✓ 2015: Total Pop=2,781, Asian Pop=633
#     ✓ 2016: Total Pop=2,769, Asian Pop=557
#     ✓ 2017: Total Pop=3,039, Asian Pop=605
#     ✓ 2018: Total Pop=3,395, Asian Pop=563
#     ✓ 2019: Total Pop=3,656, Asian Pop=622
#     → Using tract 005802 for 2020-2023
#     ✓ 2020: Total Pop=1,799, Asian Pop=167
#     ✓ 2021: Total Pop=1,936, Asian Pop=258
#     ✓ 2022: Total Pop=2,027, Asian Pop=290
#     ✓ 2023: Total Pop=1,936, Asian Pop=227
#     Error fetching 2024: Geography is not available in 2024. Available years include (2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009)
#
# 📍 Processing Cleveland...
#   ✓ 2020 GEOID: 39035107802
#     State: 39, County: 035, Tract: 107802
#     → Using tract 107802 for default
#     ✓ 2010: Total Pop=2,318, Asian Pop=472
#     ✓ 2011: Total Pop=2,752, Asian Pop=476
#     ✓ 2012: Total Pop=2,830, Asian Pop=462
#     ✓ 2013: Total Pop=3,337, Asian Pop=609
#     ✓ 2014: Total Pop=3,738, Asian Pop=586
#     ✓ 2015: Total Pop=4,344, Asian Pop=657
#     ✓ 2016: Total Pop=4,342, Asian Pop=744
#     ✓ 2017: Total Pop=4,325, Asian Pop=622
#     ✓ 2018: Total Pop=4,108, Asian Pop=667
#     ✓ 2019: Total Pop=3,969, Asian Pop=827
#     ✓ 2020: Total Pop=3,855, Asian Pop=825
#     ✓ 2021: Total Pop=3,935, Asian Pop=929
#     ✓ 2022: Total Pop=3,849, Asian Pop=825
#     ✓ 2023: Total Pop=4,352, Asian Pop=1,149
#     Error fetching 2024: Geography is not available in 2024. Available years include (2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009)
#
# 📍 Processing Chicago...
#   ✓ 2020 GEOID: 17031841100
#     State: 17, County: 031, Tract: 841100
#     → Using tract 841100 for default
#     ✓ 2010: Total Pop=6,970, Asian Pop=5,926
#     ✓ 2011: Total Pop=7,279, Asian Pop=6,192
#     ✓ 2012: Total Pop=7,011, Asian Pop=5,953
#     ✓ 2013: Total Pop=7,536, Asian Pop=6,609
#     ✓ 2014: Total Pop=7,622, Asian Pop=6,691
#     ✓ 2015: Total Pop=7,673, Asian Pop=6,762
#     ✓ 2016: Total Pop=7,308, Asian Pop=6,554
#     ✓ 2017: Total Pop=6,821, Asian Pop=6,128
#     ✓ 2018: Total Pop=7,072, Asian Pop=6,269
#     ✓ 2019: Total Pop=7,142, Asian Pop=6,166
#     ✓ 2020: Total Pop=7,165, Asian Pop=6,084
#     ✓ 2021: Total Pop=7,065, Asian Pop=6,050
#     ✓ 2022: Total Pop=6,990, Asian Pop=5,661
#     ✓ 2023: Total Pop=7,661, Asian Pop=6,441
#     Error fetching 2024: Geography is not available in 2024. Available years include (2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009)
#
# 📍 Processing Seattle...
#     Request error (attempt 1/3): HTTPSConnectionPool(host='geocoding.geo.census.gov', port=443): Max retries exceeded with url: /geocoder/geographies/onelineaddress?address=668+S+King+St%2C+Seattle%2C+WA+98104&benchmark=Public_AR_Current&vintage=Current_Current&format=json (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:992)')))
#   ✓ 2020 GEOID: 53033009100
#     State: 53, County: 033, Tract: 009100
#     → Using tract 009100 for default
#     ✓ 2010: Total Pop=2,319, Asian Pop=1,670
#     ✓ 2011: Total Pop=2,416, Asian Pop=1,530
#     ✓ 2012: Total Pop=2,744, Asian Pop=1,590
#     ✓ 2013: Total Pop=2,569, Asian Pop=1,366
#     ✓ 2014: Total Pop=2,526, Asian Pop=1,295
#     ✓ 2015: Total Pop=2,693, Asian Pop=1,465
#     ✓ 2016: Total Pop=2,766, Asian Pop=1,466
#     ✓ 2017: Total Pop=2,420, Asian Pop=1,381
#     ✓ 2018: Total Pop=2,464, Asian Pop=1,525
#     ✓ 2019: Total Pop=2,637, Asian Pop=1,636
#     ✓ 2020: Total Pop=2,813, Asian Pop=1,787
#     ✓ 2021: Total Pop=2,707, Asian Pop=1,636
#     ✓ 2022: Total Pop=2,762, Asian Pop=1,591
#     ✓ 2023: Total Pop=3,173, Asian Pop=1,859
#     Error fetching 2024: Geography is not available in 2024. Available years include (2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009)
#
# 📍 Processing Portland...
#   ✓ 2020 GEOID: 41051005103
#     State: 41, County: 051, Tract: 005103
#   ✓ 2010 GEOID: 41051005100 (via crosswalk)
#     → Using tract 005100 for 2010-2019
#     ✓ 2010: Total Pop=6,042, Asian Pop=202
#     ✓ 2011: Total Pop=6,541, Asian Pop=296
#     ✓ 2012: Total Pop=6,810, Asian Pop=392
#     ✓ 2013: Total Pop=7,352, Asian Pop=487
#     ✓ 2014: Total Pop=7,610, Asian Pop=308
#     ✓ 2015: Total Pop=7,393, Asian Pop=274
#     ✓ 2016: Total Pop=7,444, Asian Pop=321
#     ✓ 2017: Total Pop=7,948, Asian Pop=264
#     ✓ 2018: Total Pop=8,148, Asian Pop=434
#     ✓ 2019: Total Pop=8,816, Asian Pop=524
#     → Using tract 005103 for 2020-2023
#     ✓ 2020: Total Pop=2,805, Asian Pop=126
#     ✓ 2021: Total Pop=2,302, Asian Pop=89
#     ✓ 2022: Total Pop=2,885, Asian Pop=134
#     ✓ 2023: Total Pop=3,329, Asian Pop=141
#     Error fetching 2024: Geography is not available in 2024. Available years include (2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009)
#
# 📍 Processing Oakland...
#     Request error (attempt 1/3): HTTPSConnectionPool(host='geocoding.geo.census.gov', port=443): Max retries exceeded with url: /geocoder/geographies/onelineaddress?address=388+9th+St%2C+Oakland%2C+CA+94607&benchmark=Public_AR_Current&vintage=Current_Current&format=json (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:992)')))
#   ✓ 2020 GEOID: 06001403000
#     State: 06, County: 001, Tract: 403000
#     → Using tract 403000 for default
#     ✓ 2010: Total Pop=2,434, Asian Pop=2,096
#     ✓ 2011: Total Pop=2,267, Asian Pop=1,830
#     ✓ 2012: Total Pop=2,265, Asian Pop=1,929
#     ✓ 2013: Total Pop=2,368, Asian Pop=2,023
#     ✓ 2014: Total Pop=2,471, Asian Pop=2,026
#     ✓ 2015: Total Pop=2,704, Asian Pop=2,303
#     ✓ 2016: Total Pop=3,167, Asian Pop=2,607
#     ✓ 2017: Total Pop=3,251, Asian Pop=2,701
#     ✓ 2018: Total Pop=2,969, Asian Pop=2,424
#     ✓ 2019: Total Pop=2,905, Asian Pop=2,366
#     ✓ 2020: Total Pop=2,850, Asian Pop=2,182
#     ✓ 2021: Total Pop=2,907, Asian Pop=2,373
#     ✓ 2022: Total Pop=2,897, Asian Pop=2,222
#     ✓ 2023: Total Pop=3,125, Asian Pop=2,229
#     Error fetching 2024: Geography is not available in 2024. Available years include (2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009)
#
# 📍 Processing San Francisco...
#   ✓ 2020 GEOID: 06075011300
#     State: 06, County: 075, Tract: 011300
#     → Using tract 011300 for default
#     ✓ 2010: Total Pop=3,507, Asian Pop=3,163
#     ✓ 2011: Total Pop=3,331, Asian Pop=2,817
#     ✓ 2012: Total Pop=3,267, Asian Pop=2,663
#     ✓ 2013: Total Pop=3,204, Asian Pop=2,494
#     ✓ 2014: Total Pop=3,058, Asian Pop=2,244
#     ✓ 2015: Total Pop=2,885, Asian Pop=2,110
#     ✓ 2016: Total Pop=3,061, Asian Pop=2,228
#     ✓ 2017: Total Pop=2,907, Asian Pop=2,147
#     ✓ 2018: Total Pop=3,046, Asian Pop=2,336
#     ✓ 2019: Total Pop=2,843, Asian Pop=2,231
#     ✓ 2020: Total Pop=2,920, Asian Pop=2,222
#     ✓ 2021: Total Pop=2,801, Asian Pop=2,224
#     ✓ 2022: Total Pop=2,862, Asian Pop=2,218
#     ✓ 2023: Total Pop=2,518, Asian Pop=1,797
#     Error fetching 2024: Geography is not available in 2024. Available years include (2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009)
#
# 📍 Processing Fresno...
#   ✓ 2020 GEOID: 06019000300
#     State: 06, County: 019, Tract: 000300
#     → Using tract 000300 for default
#     ✓ 2010: Total Pop=3,516, Asian Pop=116
#     ✓ 2011: Total Pop=3,641, Asian Pop=159
#     ✓ 2012: Total Pop=3,721, Asian Pop=120
#     ✓ 2013: Total Pop=3,506, Asian Pop=214
#     ✓ 2014: Total Pop=3,640, Asian Pop=236
#     ✓ 2015: Total Pop=3,238, Asian Pop=185
#     ✓ 2016: Total Pop=3,270, Asian Pop=203
#     ✓ 2017: Total Pop=3,716, Asian Pop=179
#     ✓ 2018: Total Pop=3,936, Asian Pop=131
#     ✓ 2019: Total Pop=4,225, Asian Pop=104
#     ✓ 2020: Total Pop=4,927, Asian Pop=95
#     ✓ 2021: Total Pop=4,276, Asian Pop=48
#     ✓ 2022: Total Pop=3,906, Asian Pop=117
#     ✓ 2023: Total Pop=3,941, Asian Pop=270
#     Error fetching 2024: Geography is not available in 2024. Available years include (2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009)
#
#       Oakland  2013       2368       2023 06001403000
#       Oakland  2014       2471       2026 06001403000
#       Oakland  2015       2704       2303 06001403000
#       Oakland  2016       3167       2607 06001403000
#       Oakland  2017       3251       2701 06001403000
#       Oakland  2018       2969       2424 06001403000
#       Oakland  2019       2905       2366 06001403000
#       Oakland  2020       2850       2182 06001403000
#       Oakland  2021       2907       2373 06001403000
#       Oakland  2022       2897       2222 06001403000
#       Oakland  2023       3125       2229 06001403000
# San Francisco  2010       3507       3163 06075011300
# San Francisco  2011       3331       2817 06075011300
# San Francisco  2012       3267       2663 06075011300
# San Francisco  2013       3204       2494 06075011300
# San Francisco  2014       3058       2244 06075011300
# San Francisco  2015       2885       2110 06075011300
# San Francisco  2016       3061       2228 06075011300
# San Francisco  2017       2907       2147 06075011300
# San Francisco  2018       3046       2336 06075011300
# San Francisco  2019       2843       2231 06075011300
# San Francisco  2020       2920       2222 06075011300
# San Francisco  2021       2801       2224 06075011300
# San Francisco  2022       2862       2218 06075011300
# San Francisco  2023       2518       1797 06075011300
#        Fresno  2010       3516        116 06019000300
#        Fresno  2011       3641        159 06019000300
#        Fresno  2012       3721        120 06019000300
#        Fresno  2013       3506        214 06019000300
#        Fresno  2014       3640        236 06019000300
#        Fresno  2015       3238        185 06019000300
#        Fresno  2016       3270        203 06019000300
#        Fresno  2017       3716        179 06019000300
#        Fresno  2018       3936        131 06019000300
#        Fresno  2019       4225        104 06019000300
#        Fresno  2020       4927         95 06019000300
#        Fresno  2021       4276         48 06019000300
#        Fresno  2022       3906        117 06019000300
#        Fresno  2023       3941        270 06019000300
#   Los Angeles  2010       2346       1746 06037207102
#   Los Angeles  2011       2276       1760 06037207102
#   Los Angeles  2012       2268       1782 06037207102
#   Los Angeles  2013       2295       1925 06037207102
#   Los Angeles  2014       2350       1992 06037207102
#   Los Angeles  2015       2239       1791 06037207102
#   Los Angeles  2016       2366       1727 06037207102
#   Los Angeles  2017       2573       1792 06037207102
#   Los Angeles  2018       2866       1810 06037207102
#   Los Angeles  2019       2926       1695 06037207102
#   Los Angeles  2020       3181       1958 06037207102
#   Los Angeles  2021       3103       1770 06037207102
#   Los Angeles  2022       3198       1870 06037207102
#   Los Angeles  2023       3340       1782 06037207102
#
# ============================================================
# DATA SUMMARY
# ============================================================
# Total records collected: 168
# Cities with data: 12
# Year range: 2010 - 2023
#
# Records per city:
# city
# Boston           14
# Chicago          14
# Cleveland        14
# Fresno           14
# Los Angeles      14
# New York         14
# Oakland          14
# Philadelphia     14
# Portland         14
# San Francisco    14
# Seattle          14
# Washington DC    14
# dtype: int64
#
# ✅ Data saved to chinatown_demographics.csv

# %%
df_demo = pd.read_csv('chinatown_demographics.csv')
df_housing = pd.read_csv('chinatown_housing_economics.csv')

df_merged = pd.merge(df_demo, df_housing, 
                     on=['city', 'year', 'tract_geoid'], 
                     how='left',
                     suffixes=('_demo', '_housing'))

df_merged.to_csv('merged.csv', index=False)
